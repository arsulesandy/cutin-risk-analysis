# %% [markdown]
# # Indicator sanity checks
# Add quick checks for indicator calculations here.

# %%
H=[[0,1,14,15],[3,2,13,12],[4,7,8,11],[5,6,9,10]]
code=16772
print('\n'.join(' '.join(str((code>>H[r][c])&1) for c in range(3)) for r in range(3)))
# Out:
# 0 0 1
# 0 1 0
# 0 1 1

# %%
H=[[0,1,14,15],[3,2,13,12],[4,7,8,11],[5,6,9,10]]
code=int("4006",16)

print('\n'.join(' '.join(str((code>>H[r][c])&1) for c in range(3)) for r in range(3)))
