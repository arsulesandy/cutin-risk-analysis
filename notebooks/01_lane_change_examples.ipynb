# %% [markdown]
# # Lane change examples
# Add qualitative examples and plots here.

# %%
python3 scripts/step03_cutin_report.py
# Out:
#   Cell In[1], line 1
#     python3 scripts/step03_cutin_report.py
#             ^
# SyntaxError: invalid syntax
